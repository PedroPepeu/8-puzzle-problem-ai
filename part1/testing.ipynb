# %%
class Node:
    def __init__(self, value, parent=None):
        self._value = value
        self._parent = parent
        self._sons = [None] * 4
    
    def get_value(self):
        return self._value

    def set_value(self, value):
        self._value = value

    def get_parent(self):
        return self._parent

    def set_parent(self, parent):
        self._parent = parent

    def get_sons(self):
        return self._sons

    def set_son(self, index, son):
        if 0 <= index < 4:
            self._sons[index] = son
        else:
            raise IndexError("Index out of bounds. Must be between 0 and 3.")

# %%
class MatrixOperations:
    
    def __init__(self) -> None:
        pass

    def find_zero(self, sample):
        for i in range(len(sample)):
            for j in range(len(sample[i])):
                if sample[i][j] == 0:
                    return i, j

    def move_up(self, sample):
        x, y = self.find_zero(sample)
        
        if x - 1 >= 0:
            sample[x][y], sample[x - 1][y] = sample[x - 1][y], sample[x][y]
            return sample
        else:
            return []

    def move_down(self, sample):
        x, y = self.find_zero(sample)
        
        if x + 1 < len(sample):
            sample[x][y], sample[x + 1][y] = sample[x + 1][y], sample[x][y]
            return sample
        else:
            return []

    def move_left(self, sample):
        x, y = self.find_zero(sample)
        
        if y - 1 >= 0:
            sample[x][y], sample[x][y - 1] = sample[x][y - 1], sample[x][y]
            return sample
        else:
            return []


    def move_right(self, sample):
        x, y = self.find_zero(sample)
    
        if y + 1 < len(sample[0]):
            sample[x][y], sample[x][y + 1] = sample[x][y + 1], sample[x][y]
            return sample
        else:
            return []

# %%
class first_implementation:
    def __init__(self, root_value, goal_sample):
        self.root = Node(value=root_value)
        self.goal_sample = Node(value=goal_sample)
        
    def depth_first_search(self, node, target_value):
        if node is None:
            return None
        
        if node.get_value() == target_value:
            return node
        
        for son in node.get_sons():
            result = self.depth_first_search(son, target_value)
            if result is not None:
                return result
        
        return None
    
    def put(self, node, value):
        if node is None:
            return None
        
        for i in range(4):
            if node.get_sons()[i] is None:
                new_node = Node(value=value, parent=node)
                node.set_son(i, new_node)
                return new_node

        for son in node.get_sons():
            result = self.put(son, value)
            if result is not None:
                return result
        
        return None
    
    def generate_samples(self, node, depth, cur_depth, mov):
        
        movements = {
            'none': None,
            'up': MatrixOperations.move_up,
            'down': MatrixOperations.move_down,
            'left': MatrixOperations.move_left,
            'right': MatrixOperations.move_right
        }

        if node is None:
            node.set_value(node.get_parent().get_value())
            node.set_value(movements.get(mov, lambda s: s)(node.getValue()))

        if node.get_value() == self.goal_sample:
            print("Solution found")
        
        if depth == cur_depth:
            return node
        
        directions = [
            ('left', node.setLeftLeftNode),
            ('right', node.setLeftRightNode),
            ('up', node.setRightUpNode),
            ('down', node.setRightDownNode)
        ]

        for direction, setter in directions:
            setter(self._generate_samples(getattr(node, f'get{direction.capitalize()}Node')(), depth, cur_depth + 1, direction))

# %%
root = [
    [8, 0, 6],
    [3, 2, 7],
    [4, 5, 1]
]

goal = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 0]
]

t = first_implementation(root_value=root, goal_sample=goal)

t.generate_samples(root, 10, 0, 'none')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 15
#       7 goal = [
#       8     [1, 2, 3],
#       9     [4, 5, 6],
#      10     [7, 8, 0]
#      11 ]
#      13 t = first_implementation(root_value=root, goal_sample=goal)
# ---> 15 t.generate_samples(root, 10, 0, 'none')
#
# Cell In[7], line 51, in first_implementation.generate_samples(self, node, depth, cur_depth, mov)
#      48     node.set_value(node.get_parent().get_value())
#      49     node.set_value(movements.get(mov, lambda s: s)(node.getValue()))
# ---> 51 if node.get_value() == self.goal_sample:
#      52     print("Solution found")
#      54 if depth == cur_depth:
#
# AttributeError: 'list' object has no attribute 'get_value'
